# %%
# %sql
USE CATALOG ecommerce;
CREATE SCHEMA IF NOT EXISTS raw;
CREATE EXTERNAL VOLUME IF NOT EXISTS raw.rawlanding
LOCATION 'abfss://ecomm-raw-data@abiecommerceadlsdev.dfs.core.windows.net/'
COMMENT 'landing zone for raw data';

# %% [markdown]
# test commit
